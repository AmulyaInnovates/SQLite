# %%
from google.colab import files
file= files.upload()
# Out:
#      <input type="file" id="files-9a5d88e8-dadd-4637-bdc5-ded46cc82e98" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a5d88e8-dadd-4637-bdc5-ded46cc82e98">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sqlite3
database="database.sqlite"
conn= sqlite3.connect(database)
print("Connection established successfully.")
# Out:
# Connection established successfully.

# %%
import pandas as pd
tables= pd.read_sql('''SELECT * FROM sqlite_master WHERE type= 'table';''',conn)
tables
# Out:
#      type             name         tbl_name  rootpage  \
# 0   table           Player           Player         2
# 1   table       Extra_Runs       Extra_Runs         3
# 2   table   Batsman_Scored   Batsman_Scored         7
# 3   table    Batting_Style    Batting_Style        10
# 4   table    Bowling_Style    Bowling_Style        11
# 5   table          Country          Country        12
# 6   table           Season           Season        14
# 7   table             City             City        15
# 8   table          Outcome          Outcome        16
# 9   table           Win_By           Win_By        17
# 10  table     Wicket_Taken     Wicket_Taken        18
# 11  table            Venue            Venue        21
# 12  table       Extra_Type       Extra_Type        23
# 13  table         Out_Type         Out_Type        24
# 14  table    Toss_Decision    Toss_Decision        25
# 15  table           Umpire           Umpire        26
# ...

# %%
city= pd.read_sql('''SELECT * FROM City;''',conn)
city.head(5)
# Out:
#    City_Id   City_Name  Country_id
# 0        1   Bangalore           1
# 1        2  Chandigarh           1
# 2        3       Delhi           1
# 3        4      Mumbai           1
# 4        5     Kolkata           1

# %%
country= pd.read_sql('''SELECT * FROM Country;''',conn)
country.head(5)
# Out:
#    Country_Id  Country_Name
# 0           1         India
# 1           2  South Africa
# 2           3         U.A.E
# 3           4   New Zealand
# 4           5     Australia

# %%
join_inner= pd.read_sql('''SELECT c.Country_Id, c.Country_Name, ci.City_Name
FROM Country c
INNER JOIN City ci
ON c.Country_Id == ci.Country_id;''',conn)

join_inner
# Out:
#     Country_Id  Country_Name       City_Name
# 0            1         India       Bangalore
# 1            1         India      Chandigarh
# 2            1         India           Delhi
# 3            1         India          Mumbai
# 4            1         India         Kolkata
# 5            1         India          Jaipur
# 6            1         India       Hyderabad
# 7            1         India         Chennai
# 8            2  South Africa       Cape Town
# 9            2  South Africa  Port Elizabeth
# 10           2  South Africa          Durban
# 11           2  South Africa       Centurion
# 12           2  South Africa     East London
# 13           2  South Africa    Johannesburg
# 14           2  South Africa       Kimberley
# 15           2  South Africa    Bloemfontein
# 16           1         India       Ahmedabad
# 17           1         India         Cuttack
# 18           1         India          Nagpur
# 19           1         India      Dharamsala
# ...

# %%
Player= pd.read_sql('''SELECT * FROM Player;''',conn)
Player.head(5)
# Out:
#    Player_Id      Player_Name                  DOB  Batting_hand  \
# 0          1       SC Ganguly  1972-07-08 00:00:00             1
# 1          2      BB McCullum  1981-09-27 00:00:00             2
# 2          3       RT Ponting  1974-12-19 00:00:00             2
# 3          4        DJ Hussey  1977-07-15 00:00:00             2
# 4          5  Mohammad Hafeez  1980-10-17 00:00:00             2
#
#    Bowling_skill  Country_Name
# 0            1.0             1
# 1            1.0             4
# 2            1.0             5
# 3            2.0             5
# 4            2.0             6

# %%
season= pd.read_sql('''SELECT * FROM season;''',conn)
season.head(5)
# Out:
#    Season_Id  Man_of_the_Series  Orange_Cap  Purple_Cap  Season_Year
# 0          1                 32         100         102         2008
# 1          2                 53          18          61         2009
# 2          3                133         133         131         2010
# 3          4                162         162         194         2011
# 4          5                315         162         190         2012

# %%
Outer_Join= pd.read_sql('''SELECT * FROM Player p
LEFT JOIN season s
ON p.Player_Id == s.Man_of_the_Series;''',conn)

Outer_Join.head(5)
# Out:
#    Player_Id      Player_Name                  DOB  Batting_hand  \
# 0          1       SC Ganguly  1972-07-08 00:00:00             1
# 1          2      BB McCullum  1981-09-27 00:00:00             2
# 2          3       RT Ponting  1974-12-19 00:00:00             2
# 3          4        DJ Hussey  1977-07-15 00:00:00             2
# 4          5  Mohammad Hafeez  1980-10-17 00:00:00             2
#
#    Bowling_skill  Country_Name  Season_Id  Man_of_the_Series  Orange_Cap  \
# 0            1.0             1        NaN                NaN         NaN
# 1            1.0             4        NaN                NaN         NaN
# 2            1.0             5        NaN                NaN         NaN
# 3            2.0             5        NaN                NaN         NaN
# 4            2.0             6        NaN                NaN         NaN
#
#    Purple_Cap  Season_Year
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# ...

# %%
cross_join= pd.read_sql('''SELECT c.Country_Id, c.Country_Name, ci.City_Name
FROM Country c
INNER JOIN City ci;''',conn)

cross_join
# Out:
#      Country_Id Country_Name   City_Name
# 0             1        India   Bangalore
# 1             1        India  Chandigarh
# 2             1        India       Delhi
# 3             1        India      Mumbai
# 4             1        India     Kolkata
# ..          ...          ...         ...
# 343          12  Netherlands      Raipur
# 344          12  Netherlands      Ranchi
# 345          12  Netherlands   Abu Dhabi
# 346          12  Netherlands      Rajkot
# 347          12  Netherlands      Kanpur
#
# [348 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# cross_join['Country_Id'].plot(kind='hist', bins=20, title='Country_Id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
union_clause= pd.read_sql('''SELECT Player_Name FROM Player UNION Select Team_Name FROM Team;''',conn)

union_clause
# Out:
#         Player_Name
# 0    A Ashish Reddy
# 1        A Chandila
# 2          A Chopra
# 3        A Flintoff
# 4          A Kumble
# ..              ...
# 477     Younis Khan
# 478       YS Chahal
# 479    Yuvraj Singh
# 480     YV Takawale
# 481          Z Khan
#
# [482 rows x 1 columns]
# No charts were generated by quickchart
